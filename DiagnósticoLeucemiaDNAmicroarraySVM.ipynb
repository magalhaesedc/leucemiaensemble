# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Upload dos arquivos do dataset**

# %%
from google.colab import files
uploaded = files.upload ()
# Out:
#      <input type="file" id="files-1042f468-786e-4b13-8bf5-bfc940d04d8f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1042f468-786e-4b13-8bf5-bfc940d04d8f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving actual.csv to actual (1).csv
# Saving data_set_ALL_AML_independent.csv to data_set_ALL_AML_independent (1).csv
# Saving data_set_ALL_AML_train.csv to data_set_ALL_AML_train (1).csv

# %% [markdown]
# **Leitura dos arquivos para uso no programa**

# %%
labels = pd.read_csv('actual.csv', index_col = 'patient')
test = pd.read_csv('data_set_ALL_AML_independent.csv')
train = pd.read_csv('data_set_ALL_AML_train.csv')
train.head()
# Out:
#                       Gene Description Gene Accession Number  ...   33 call.37
# 0  AFFX-BioB-5_at (endogenous control)        AFFX-BioB-5_at  ... -135       A
# 1  AFFX-BioB-M_at (endogenous control)        AFFX-BioB-M_at  ... -186       A
# 2  AFFX-BioB-3_at (endogenous control)        AFFX-BioB-3_at  ...  -70       A
# 3  AFFX-BioC-5_at (endogenous control)        AFFX-BioC-5_at  ...  337       A
# 4  AFFX-BioC-3_at (endogenous control)        AFFX-BioC-3_at  ... -407       A
#
# [5 rows x 78 columns]

# %% [markdown]
# **Limpeza e Preparação dos Dados**

# %%
cols = [col for col in test.columns if 'call' in col]
test = test.drop(cols, 1)

cols = [col for col in train.columns if 'call' in col]
train = train.drop(cols, 1)

train.head()
# Out:
#                       Gene Description Gene Accession Number  ...   32   33
# 0  AFFX-BioB-5_at (endogenous control)        AFFX-BioB-5_at  ... -124 -135
# 1  AFFX-BioB-M_at (endogenous control)        AFFX-BioB-M_at  ...  -79 -186
# 2  AFFX-BioB-3_at (endogenous control)        AFFX-BioB-3_at  ...  -37  -70
# 3  AFFX-BioC-5_at (endogenous control)        AFFX-BioC-5_at  ...  330  337
# 4  AFFX-BioC-3_at (endogenous control)        AFFX-BioC-3_at  ... -188 -407
#
# [5 rows x 40 columns]

# %%
train = train.T
test = test.T
train.head()
# Out:
#                                                       0     ...                       7128
# Gene Description       AFFX-BioB-5_at (endogenous control)  ...  GB DEF = mRNA (clone 1A7)
# Gene Accession Number                       AFFX-BioB-5_at  ...                Z78285_f_at
# 1                                                     -214  ...                        -37
# 2                                                     -139  ...                        -14
# 3                                                      -76  ...                        -41
#
# [5 rows x 7129 columns]

# %%
train = train.drop(['Gene Description', 'Gene Accession Number'])
test = test.drop(['Gene Description', 'Gene Accession Number'])

train.head()
# Out:
#    0     1     2    3     4     5     6     ... 7122  7123  7124 7125 7126 7127 7128
# 1  -214  -153   -58   88  -295  -558   199  ...  389   -37   793  329   36  191  -37
# 2  -139   -73    -1  283  -264  -400  -330  ...  442   -17   782  295   11   76  -14
# 3   -76   -49  -307  309  -376  -650    33  ...  168    52  1138  777   41  228  -41
# 4  -135  -114   265   12  -419  -585   158  ...  174  -110   627  170  -50  126  -91
# 5  -106  -125   -76  168  -230  -284     4  ...  504   -26   250  314   14   56  -25
#
# [5 rows x 7129 columns]

# %%
labels = labels.replace({'ALL':0,'AML':1})
labels_train = labels[labels.index <= 38]
labels_test = labels[labels.index > 38]

train = train.replace(np.inf, np.nan)
train = train.fillna(value = train.values.mean())

test = test.replace(np.inf, np.nan)
test = test.fillna(value = test.values.mean())

# %% [markdown]
# **Juntamos os conjuntos de treinamento e de teste para terem as mesmas colunas depois de aplicar o PCA**

# %%
df_all = train.append(test, ignore_index=True)

# %% [markdown]
# **Pré-Processamento (normalização) e Redução da Dimensionalidade (com PCA)**

# %%
from sklearn import preprocessing
X_all = preprocessing.StandardScaler().fit_transform(df_all)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=50, random_state=42)
X_pca = pca.fit_transform(X_all)
print(X_pca.shape)
# Out:
# (72, 50)

# %% [markdown]
# **Classificação com Vetor de Suporte (SVC)**

# %%
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier as XGB
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
model = SVC()
model.fit(X_pca[:38,:], labels_train.values.ravel())
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
pred = model.predict(X_pca[38:,:])
print('Accuracy: ', accuracy_score(labels_test, pred))
# Out:
# Accuracy:  0.6764705882352942

# %%
cm_svm = confusion_matrix(labels_test, pred)

ax = plt.subplot()
sns.heatmap(cm_svm, annot=True, ax = ax, fmt='g', cmap='Greens') 

# Labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels') 
ax.set_title('SVM Confusion Matrix') 
ax.xaxis.set_ticklabels(labels) 
ax.yaxis.set_ticklabels(labels, rotation=360);
